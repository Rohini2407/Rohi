# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohini2407/Rohi/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-503a21f1-4ea6-4b1d-bd29-3649e88862f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-503a21f1-4ea6-4b1d-bd29-3649e88862f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("Customers.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
df.sort_values(by=['Profession','Annual Income ($)'],ascending=[True,False],inplace=True)

# %%
df[['Profession','Annual Income ($)']].head(10)
# Out:
#      Profession  Annual Income ($)
# 1825     Artist             189709
# 1165     Artist             189498
# 658      Artist             189446
# 921      Artist             189091
# 652      Artist             189072
# 970      Artist             188620
# 1293     Artist             187898
# 1041     Artist             187841
# 416      Artist             187667
# 1306     Artist             187643

# %%
df.nsmallest(10,'Spending Score (1-100)')
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 249          250  Female   89              65000                       0
# 202          203  Female   16              60000                       0
# 514          515    Male   81              83771                       1
# 1435        1436  Female   18              82812                       1
# 391          392    Male    1              89144                       1
# 1080        1081  Female   81             155396                       1
# 1547        1548  Female   91             107323                       1
# 1050        1051    Male   46             149764                       1
# 544          545  Female   33              88763                       1
# 1623        1624    Male   81              71543                       1
#
#          Profession  Work Experience  Family Size
# 249        Engineer                0            5
# 202        Engineer                6            8
# ...

# %%
df.nlargest(10,'Annual Income ($)')
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 569          570  Female   91             189974                      37
# 1257        1258    Male   60             189945                      20
# 1825        1826    Male    7             189709                      18
# 1576        1577  Female   16             189689                      37
# 638          639  Female   59             189672                       8
# 1801        1802    Male   20             189650                      60
# 736          737  Female   33             189630                      53
# 1165        1166    Male   19             189498                      18
# 658          659  Female   31             189446                      38
# 805          806  Female   30             189369                      69
#
#       Profession  Work Experience  Family Size
# 569     Engineer                8            1
# 1257    Engineer                0            5
# ...

# %%
df['Profession'].value_counts()
# Out:
# Artist           612
# Healthcare       339
# Entertainment    234
# Engineer         179
# Doctor           161
# Executive        153
# Lawyer           142
# Marketing         85
# Homemaker         60
# Name: Profession, dtype: int64

# %%
df['Spending Score (1-100)'].median()
# Out:
# 50.0

# %%
prof_grp = df.groupby(['Profession'])

# %%
prof_grp.get_group('Engineer')
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 569          570  Female   91             189974                      37
# 1257        1258    Male   60             189945                      20
# 777          778    Male   94             188107                      52
# 1107        1108    Male   36             187305                      85
# 1588        1589  Female   48             186445                      41
# ...          ...     ...  ...                ...                     ...
# 250          251    Male   80              20000                      93
# 289          290  Female   93              19000                      58
# 152          153  Female   44              17000                      20
# 263          264  Female   64              13000                      38
# 10            11    Male   67               7000                      14
#
#      Profession  Work Experience  Family Size
# ...

# %%
filt=df['Profession']=='Engineer'
df.loc[filt]['Gender'].value_counts()
# Out:
# Female    103
# Male       76
# Name: Gender, dtype: int64

# %%
prof_grp['Gender'].value_counts()
# Out:
# Profession     Gender
# Artist         Female    380
#                Male      232
# Doctor         Female     89
#                Male       72
# Engineer       Female    103
#                Male       76
# Entertainment  Female    133
#                Male      101
# Executive      Female     87
#                Male       66
# Healthcare     Female    196
#                Male      143
# Homemaker      Female     39
#                Male       21
# Lawyer         Female     86
#                Male       56
# Marketing      Female     53
#                Male       32
# Name: Gender, dtype: int64

# %%
prof_grp['Gender'].value_counts().loc['Doctor']
# Out:
# Gender
# Female    89
# Male      72
# Name: Gender, dtype: int64

# %%
income = prof_grp['Spending Score (1-100)'].median()

# %%
income
# Out:
# Profession
# Artist           52.0
# Doctor           50.0
# Engineer         47.0
# Entertainment    53.0
# Executive        49.0
# Healthcare       51.0
# Homemaker        45.5
# Lawyer           49.0
# Marketing        46.0
# Name: Spending Score (1-100), dtype: float64

# %%
prof_grp['Spending Score (1-100)'].median().loc['Doctor']
# Out:
# 50.0

# %%
prof_grp['Engineer'].agg(['median','mean'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-a3dd54df5b77> in <cell line: 1>()
# ----> 1 prof_grp['Engineer'].agg(['median','mean'])
#       2
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1414                 stacklevel=find_stack_level(),
#    1415             )
# -> 1416         return super().__getitem__(key)
#    1417
#    1418     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     246         else:
#     247             if key not in self.obj:
# --> 248                 raise KeyError(f"Column not found: {key}")
#     249             subset = self.obj[key]
#     250             ndim = subset.ndim
#
# KeyError: 'Column not found: Engineer'

# %%
prof_grp['Annual Income ($)'].agg(['median','mean']).loc['Engineer']
# Out:
# median    112766.000000
# mean      111161.240223
# Name: Engineer, dtype: float64

# %%
gen=prof_grp['Gender'].apply(lambda x: x.str.contains('Female').sum())

# %%
gen
# Out:
# Profession
# Artist           380
# Doctor            89
# Engineer         103
# Entertainment    133
# Executive         87
# Healthcare       196
# Homemaker         39
# Lawyer            86
# Marketing         53
# Name: Gender, dtype: int64

# %%
fem_df2=pd.concat([income,gen],axis=1,sort=False)

# %%
fem_df2
# Out:
#                Spending Score (1-100)  Gender
# Profession
# Artist                           52.0     380
# Doctor                           50.0      89
# Engineer                         47.0     103
# Entertainment                    53.0     133
# Executive                        49.0      87
# Healthcare                       51.0     196
# Homemaker                        45.5      39
# Lawyer                           49.0      86
# Marketing                        46.0      53

# %%
fem_df2.sort_values(by = 'Profession',ascending = False)
# Out:
#                Spending Score (1-100)  Gender
# Profession
# Marketing                        46.0      53
# Lawyer                           49.0      86
# Homemaker                        45.5      39
# Healthcare                       51.0     196
# Executive                        49.0      87
# Entertainment                    53.0     133
# Engineer                         47.0     103
# Doctor                           50.0      89
# Artist                           52.0     380
