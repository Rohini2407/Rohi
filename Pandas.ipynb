# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohini2407/Rohi/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-c03a11ea-65ad-4512-95bc-9106179aa920" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c03a11ea-65ad-4512-95bc-9106179aa920">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("MallCustomers.csv")

# %%
df.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Genre']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 195    Female
# 196    Female
# 197      Male
# 198      Male
# 199      Male
# Name: Genre, Length: 200, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isna().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df['Genre'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Genre, dtype: int64

# %%
df.iloc[0,2]
# Out:
# 19

# %%
df.iloc[0]
# Out:
# CustomerID                   1
# Genre                     Male
# Age                         19
# Annual Income (k$)          15
# Spending Score (1-100)      39
# Name: 0, dtype: object

# %%
df.iloc[0:11,0:2]
# Out:
#     CustomerID   Genre
# 0            1    Male
# 1            2    Male
# 2            3  Female
# 3            4  Female
# 4            5  Female
# 5            6  Female
# 6            7  Female
# 7            8  Female
# 8            9    Male
# 9           10  Female
# 10          11    Male

# %%
df.loc[0:5,'Genre':'Annual Income (k$)']  #df.loc[rows,columns]
# Out:
#     Genre  Age  Annual Income (k$)
# 0    Male   19                  15
# 1    Male   21                  15
# 2  Female   20                  16
# 3  Female   23                  16
# 4  Female   31                  17
# 5  Female   22                  17

# %%
people={
    "first":["aryan","uday","divij"],
    "last":["sonawane","talele","kulkarni"],
    "email":["aryans.nsk@gmail.com","ut@gmail.com","macenth@gmail.com"]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first      last                 email
# 0  aryan  sonawane  aryans.nsk@gmail.com
# 1   uday    talele          ut@gmail.com
# 2  divij  kulkarni     macenth@gmail.com

# %%
df.set_Index('email',inplace = True)  #used to set an index,return in bold

# %%
df.drop('email',axis = 1,inplace = True)

# %%
df.drop(2,axis = 0,inplace = True)

# %%
df2={'email':['ratspawar@gmail.com','dips@gmail.com','tans@gmail.com'],
     'first':['ratnali','deepali','tanmayi'],
     'last':['pawar','khajure','shete']}

# %%
df = df.append(df2,ignore_Index = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-8b533b09787d> in <cell line: 1>()
# ----> 1 df = df.append(df2,ignore_Index = True)
#
# TypeError: DataFrame.append() got an unexpected keyword argument 'ignore_Index'

# %%
df

# %%
filt = df['Genre'] == 'Female'

# %%
df
# Out:
#    first      last
# 0  aryan  sonawane
# 1   uday    talele

# %%
filt=df['Genre']=='Female'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Genre'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df = pd.read_csv("MallCustomers.csv")

# %%
filt=df['Genre']=='Female'

# %%
df[filt]
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# ..          ...     ...  ...                 ...                     ...
# 191         192  Female   32                 103                      69
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
#
# [112 rows x 5 columns]

# %%
filt1 = (df['Genre']=='Female')&(df['Spending Score (1-100)']>=75)

# %%
df[filt1]
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 3             4  Female   23                  16                      77
# 5             6  Female   22                  17                      76
# 7             8  Female   23                  18                      94
# 11           12  Female   35                  19                      99
# 13           14  Female   24                  20                      77
# 19           20  Female   35                  23                      98
# 29           30  Female   23                  29                      87
# 35           36  Female   21                  33                      81
# 39           40  Female   20                  37                      75
# 125         126  Female   31                  70                      77
# 135         136  Female   29                  73                      88
# 143         144  Female   32                  76                      87
# ...
